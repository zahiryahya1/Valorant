# %%
from dotenv import load_dotenv
import os

load_dotenv()
API_KEY=os.getenv("HENRIKDEV_API_KEY")

# %%
print("Loaded key:", API_KEY)
# Out:
# Loaded key: HDEV-3d713f8b-3b89-44fa-ae2b-26d9aceed44a

# %%
import requests

name = "Captain Ignant"
tag = "goat" 

headers = {
    "Authorization": API_KEY
}

url = f"https://api.henrikdev.xyz/valorant/v2/account/{name}/{tag}"

response = requests.get(url, headers = headers)

print("Status:", response.status_code)
print(response.json())
# Out:
# Status: 200
# {'status': 200, 'data': {'puuid': 'f9f26d15-776c-57a0-b6bf-be1fc1d3c443', 'region': 'na', 'account_level': 240, 'name': 'Captain Ignant', 'tag': 'goat', 'card': '1b6c643b-4f7e-aed8-88f6-f3932e682c14', 'title': '3a8f14a7-43e0-5c08-d021-41a5d8b3c983', 'platforms': ['PC', 'CONSOLE'], 'updated_at': '2026-02-27T06:27:41.456Z'}}

# %%
import json

account_data = response.json()
puuid = account_data.get("data", {}).get("puuid")
region = account_data.get("data", {}).get("region")


match_url = f"https://api.henrikdev.xyz/valorant/v3/by-puuid/matches/{region}/{puuid}"

response = requests.get(match_url, headers=headers)

print("Status:", response.status_code)

with open("matches.json", "w") as f:
    json.dump(response.json(), f, indent=4)
# Out:
# Status: 200
